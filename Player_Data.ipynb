# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import json
import re

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#Get scoring data from cricket api
def get_url_metadata(match_id):
    url = f'https://cricketapi.platform.iplt20.com//fixtures/{match_id}/scoring'
    return url

#Get the data in the parsed html format
def get_soup_from_url(url):
    try:
        html = urlopen(url).read()
    except HTTPError:
        print("Link Cannot be Reached", url)
        return -1
        
    #soup = BeautifulSoup(html,"lxml")
    soup = BeautifulSoup(html,"html.parser")
    return str(soup)

# %%
def get_metadata_df_from_matchid(match_id):
  m = json.loads(get_soup_from_url(get_url_metadata(match_id)))
  this_match = pd.DataFrame([{k: v for k,v in m['matchInfo'].items() if k in [
    'matchDate', 'matchEndDate','isLimitedOvers', 'description', 'matchType', 'tournamentLabel']}])
  this_match['match_id'] = match_id
  try:
      this_match['toss_elected'] = m['matchInfo']['additionalInfo']['toss.elected']
  except:
      this_match['toss_elected'] = ''
  this_match['venue_id'] = m['matchInfo']['venue']['id']
  try:
      this_match['team1_wk'] = m['matchInfo']['teams'][0]['wicketKeeper']['id']
      this_match['team2_wk'] = m['matchInfo']['teams'][1]['wicketKeeper']['id']
  except:
      this_match['team1_wk'] = ''
      this_match['team2_wk'] = ''
  this_match['team1'] = m['matchInfo']['teams'][0]['team']['fullName']
  this_match['team2'] = m['matchInfo']['teams'][1]['team']['fullName']
  match_df = this_match
  venue_df = pd.DataFrame([m['matchInfo']['venue']])
  player_df = pd.concat([pd.DataFrame(m['matchInfo']['teams'][0]['players']),
                         pd.DataFrame(m['matchInfo']['teams'][1]['players'])]).drop_duplicates()
  
  #venue_df.drop('coordinates',axis=1, inplace=True)
  player_df['batter_hand'] = player_df.rightHandedBat.apply(lambda x: 'R' if x else 'L')
  player_df['bowler_hand'] = player_df.rightArmedBowl.apply(lambda x: 'R' if x else 'L')
  match_df.matchType = match_df.apply(lambda x: 'W_' + x.matchType if 
               re.search('women', x.tournamentLabel.lower()) else x.matchType,
              axis=1)
  match_df['toss_winner'] = match_df.toss_elected.apply(lambda x: str(x).strip().lower().split(',')[0])
  match_df['toss_decision'] = match_df.toss_elected.apply(lambda x: str(x).lower().strip('.').split(' ')[-1])
  match_df['toss_decision'] = match_df.toss_decision.apply(lambda x: 'field' if str(x)=='bowl' else str(x))
  match_df['toss_decision'] = match_df.toss_decision.apply(lambda x: x if str(x) in ['field','bat'] else '')
  match_df.drop('toss_elected', axis=1, inplace=True)
  return {'match_metadata': match_df,
          'player_metadata': player_df,
          'venue_metadata': venue_df}

# %%
S_2012=pd.read_csv('S_2012.csv',header=None)
S_2013=pd.read_csv('S_2013.csv',header=None)
S_2014=pd.read_csv('S_2014.csv',header=None)
S_2015=pd.read_csv('S_2015.csv',header=None)
S_2016=pd.read_csv('S_2016.csv',header=None)
S_2017=pd.read_csv('S_2017.csv',header=None)
S_2018=pd.read_csv('S_2018.csv',header=None)
S_2019=pd.read_csv('S_2019.csv',header=None)
S_2020=pd.read_csv('S_2020.csv',header=None)
S_2021=pd.read_csv('S_2021.csv',header=None)

# %%
def get_player_metadata(season):
    df=[]
    for i in range(len(season)):
        ID=int(season.iloc[i])
        try:
            a=get_metadata_df_from_matchid(ID)
            a_player=a['player_metadata']
            df.append(a_player)
        except Exception:
            pass
    data_f=pd.concat(df)   
    final_player=data_f.drop_duplicates()
    final_player.drop(['rightArmedBowl', 'rightHandedBat'], axis=1, inplace=True)
    return(final_player)

# %%
players_2012=get_player_metadata(S_2012)
players_2013=get_player_metadata(S_2013)
players_2014=get_player_metadata(S_2014)
players_2015=get_player_metadata(S_2015)
players_2016=get_player_metadata(S_2016)
players_2017=get_player_metadata(S_2017)
players_2018=get_player_metadata(S_2018)
players_2019=get_player_metadata(S_2019)
players_2020=get_player_metadata(S_2020)
players_2021=get_player_metadata(S_2021)
# Out:
# /Users/omkar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
frames=[players_2012,players_2013,players_2014,players_2015,players_2016,players_2017,players_2018,players_2019,players_2020,players_2021]

# %%
players=pd.concat(frames)

# %%
players_final=players.drop_duplicates()

# %%
players_final.to_csv('players.csv',index=False)

# %%
players_2012
# Out:
#      id                         fullName        shortName    nationality  \
# 0     7                     Murali Vijay          M Vijay         Indian
# 1    24                   Faf du Plessis     F du Plessis  South African
# 2    12            Subramaniam Badrinath      S Badrinath         Indian
# 3    14                     Suresh Raina          S Raina         Indian
# 4     1                         MS Dhoni         MS Dhoni         Indian
# 5    25                     Dwayne Bravo         DJ Bravo    West Indian
# 6     9                  Ravindra Jadeja         R Jadeja         Indian
# 7    26                     Albie Morkel         A Morkel  South African
# 8     8              Ravichandran Ashwin         R Ashwin         Indian
# 9    10                    Shadab Jakati         S Jakati         Indian
# 10   18                   Doug Bollinger      D Bollinger     Australian
# 0    97                 Sachin Tendulkar      S Tendulkar         Indian
# 1   266                     Richard Levi           R Levi  South African
# 2   100                    Ambati Rayudu         A Rayudu         Indian
# 3   107                     Rohit Sharma         R Sharma         Indian
# 4   102                   Dinesh Karthik        D Karthik         Indian
# 5   210                   Kieron Pollard        K Pollard    West Indian
# 6   209                   James Franklin       J Franklin  New Zealander
# 7   103                  Harbhajan Singh          H Singh         Indian
# 8   211                   Lasith Malinga        L Malinga     Sri Lankan
# 9    98                       Abu Nechim         A Nechim         Indian
# 10  106                     Pragyan Ojha           P Ojha         Indian
# 0    84                   Gautam Gambhir        G Gambhir         Indian
# 1   198                   Jacques Kallis         J Kallis  South African
# 2    89                     Manoj Tiwary         M Tiwary         Indian
# 3    96                     Yusuf Pathan         Y Pathan         Indian
# 4   202                 Brendon McCullum       B McCullum  New Zealander
# 5    88               Laxmi Ratan Shukla   L Ratan Shukla         Indian
# 6    92                     Rajat Bhatia         R Bhatia         Indian
# 7   196                        Brett Lee            B Lee     Australian
# 8    85                    Iqbal Abdulla        I Abdulla         Indian
# 9   204                Marchant de Lange       M de Lange  South African
# 10  259                    Debabrata Das            D Das         Indian
# 0    52                       Naman Ojha           N Ojha         Indian
# 1    45                  Virender Sehwag         V Sehwag         Indian
# 2   167                      Aaron Finch          A Finch     Australian
# 3    62                    Venugopal Rao            V Rao         Indian
# 4   282                    Glenn Maxwell        G Maxwell     Australian
# 5   169                     Morne Morkel         M Morkel  South African
# 6    49                     Irfan Pathan         I Pathan         Indian
# 8    34                     Ashish Reddy         AA Reddy         Indian
# 9   183                      Juan Theron         J Theron       American
# 0   205                   Aiden Blizzard       A Blizzard     Australian
# 9   262                     Rahul Shukla         R Shukla         Indian
# 2    20                   Michael Hussey         M Hussey     Australian
# 5   249                 Biplap Samantray      B Samantray         Indian
# 7    29                    Akshath Reddy         AP Reddy         Indian
# 2   286                   Michael Clarke         M Clarke     Australian
# 2   227                     Shane Watson         S Watson     Australian
# 5   154                      Asad Pathan         A Pathan         Indian
# 6   190                      Ryan Harris         R Harris     Australian
# 10   17                   Ben Hilfenhaus     B Hilfenhaus     Australian
# 10  253             Gurkeerat Mann Singh         GM Singh         Indian
# 9   228                       Shaun Tait           S Tait     Australian
# 5   413                     Dwayne Smith         DR Smith    West Indian
# 6   151                 Abhimanyu Mithun         A Mithun         Indian
# 7   281                    Syed Mohammad       S Mohammad         Indian
# 10  415  Prasanth Parameswaran DUPLICATE     Parameswaran
# 0   170                     David Warner         D Warner     Australian
# 10   61                      Varun Aaron          V Aaron         Indian
# 9    91                  Pradeep Sangwan        P Sangwan         Indian
# 3   267                 Anustup Majumdar       A Majumdar         Indian
# 8    83                     Ramesh Powar          R Powar         Indian
# 7   177                    Andre Russell        A Russell    West Indian
# 6    11               Srikkanth Anirudha       S Anirudha         Indian
# 0   242                   Mohnish Mishra         M Mishra         Indian
# 10  269             Krishnakant Upadhyay       K Upadhyay         Indian
# 0   212                 Herschelle Gibbs          H Gibbs  South African
# 2    60                     Unmukt Chand          U Chand         Indian
# 2   179                       Chris Lynn           C Lynn     Australian
# 6   119                   Harpreet Singh          H Singh         Indian
# 9   114                      Ali Murtaza        A Murtaza         Indian
# 10  101                  Dhawal Kulkarni       D Kulkarni         Indian
# 6   251                      Sunny Gupta          S Gupta         Indian
#
#    dateOfBirth bowlingStyle batter_hand bowler_hand
# 0   1984-04-01          NaN           L           L
# 1   1984-07-13     LEG_SPIN           R           R
# 2   1980-08-30          NaN           L           L
# 3   1986-11-27     OFF_SPIN           L           R
# 4   1981-07-07  MEDIUM_SEAM           R           R
# 5   1983-10-07  MEDIUM_SEAM           R           R
# 6   1988-12-06     ORTHODOX           L           L
# 7   1981-06-10          NaN           L           L
# 8   1986-09-17     OFF_SPIN           R           R
# 9   1980-11-27          NaN           L           L
# 10  1981-07-24          NaN           L           L
# 0   1973-04-24     OFF_SPIN           R           R
# 1   1988-01-14          NaN           R           L
# 2   1985-09-23     OFF_SPIN           R           R
# 3   1987-04-30     OFF_SPIN           R           R
# 4   1985-06-01     OFF_SPIN           R           R
# 5   1987-05-12  MEDIUM_SEAM           R           R
# 6   1980-11-07          NaN           R           L
# 7   1980-07-03     OFF_SPIN           R           R
# 8   1983-08-28    FAST_SEAM           R           R
# 9   1988-11-05  MEDIUM_SEAM           R           R
# 10  1986-09-05     ORTHODOX           L           L
# 0   1981-10-14     LEG_SPIN           L           R
# 1   1975-10-16    FAST_SEAM           R           R
# 2   1985-11-14          NaN           R           R
# 3   1982-11-17          NaN           R           L
# 4   1981-09-27  MEDIUM_SEAM           R           R
# 0   1986-10-27     LEG_SPIN           L           R
# 10  1989-10-29          NaN           R           R
# 9   1990-11-05          NaN           R           L
# 3   1984-04-30          NaN           L           L
# 8   1978-05-20          NaN           L           L
# 7   1988-04-29    FAST_SEAM           R           R
# 6   1987-04-14          NaN           L           L
# 0   1984-02-09          NaN           L           L
# 10  1986-06-18          NaN           L           L
# 0   1974-02-23     LEG_SPIN           R           R
# 2   1993-03-26          NaN           L           L
# 2   1990-04-10          NaN           R           L
# 6   1991-08-11          NaN           L           L
# 9   1990-01-01          NaN           L           L
# 10  1988-12-10  MEDIUM_SEAM           R           R
# 6   1988-09-27          NaN           L           L

# %%
# Out:
#      id               fullName     shortName    nationality dateOfBirth  \
# 0     7           Murali Vijay       M Vijay         Indian  1984-04-01
# 1    24         Faf du Plessis  F du Plessis  South African  1984-07-13
# 2    12  Subramaniam Badrinath   S Badrinath         Indian  1980-08-30
# 3    14           Suresh Raina       S Raina         Indian  1986-11-27
# 4     1               MS Dhoni      MS Dhoni         Indian  1981-07-07
# 5    25           Dwayne Bravo      DJ Bravo    West Indian  1983-10-07
# 6     9        Ravindra Jadeja      R Jadeja         Indian  1988-12-06
# 7    26           Albie Morkel      A Morkel  South African  1981-06-10
# 8     8    Ravichandran Ashwin      R Ashwin         Indian  1986-09-17
# 9    10          Shadab Jakati      S Jakati         Indian  1980-11-27
# 10   18         Doug Bollinger   D Bollinger     Australian  1981-07-24
# 0    97       Sachin Tendulkar   S Tendulkar         Indian  1973-04-24
# 1   266           Richard Levi        R Levi  South African  1988-01-14
# 2   100          Ambati Rayudu      A Rayudu         Indian  1985-09-23
# 3   107           Rohit Sharma      R Sharma         Indian  1987-04-30
# 4   102         Dinesh Karthik     D Karthik         Indian  1985-06-01
# 5   210         Kieron Pollard     K Pollard    West Indian  1987-05-12
# 6   209         James Franklin    J Franklin  New Zealander  1980-11-07
# 7   103        Harbhajan Singh       H Singh         Indian  1980-07-03
# 8   211         Lasith Malinga     L Malinga     Sri Lankan  1983-08-28
# 9    98             Abu Nechim      A Nechim         Indian  1988-11-05
# 10  106           Pragyan Ojha        P Ojha         Indian  1986-09-05
#
#     rightArmedBowl  rightHandedBat bowlingStyle batter_hand bowler_hand
# 0            False           False          NaN           L           L
# 1             True            True     LEG_SPIN           R           R
# 2            False           False          NaN           L           L
# 3             True           False     OFF_SPIN           L           R
# 4             True            True  MEDIUM_SEAM           R           R
# 5             True            True  MEDIUM_SEAM           R           R
# 6            False           False     ORTHODOX           L           L
# 7            False           False          NaN           L           L
# 8             True            True     OFF_SPIN           R           R
# 9            False           False          NaN           L           L
# 10           False           False          NaN           L           L
# 0             True            True     OFF_SPIN           R           R
# 1            False            True          NaN           R           L
# 2             True            True     OFF_SPIN           R           R
# 3             True            True     OFF_SPIN           R           R
# 4             True            True     OFF_SPIN           R           R
# 5             True            True  MEDIUM_SEAM           R           R
# 6            False            True          NaN           R           L
# 7             True            True     OFF_SPIN           R           R
# 8             True            True    FAST_SEAM           R           R
# 9             True            True  MEDIUM_SEAM           R           R
# 10           False           False     ORTHODOX           L           L
